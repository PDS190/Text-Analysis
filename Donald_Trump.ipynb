# %% [markdown]
# # Install libraries

# %% [markdown]
# ###### For snscrape : for error, check appdata and install git

# %%
pip install tweepy # for authentication
pip install textblob # for sentiment
# !pip install snscrape # old version
# !pip3 install git+https://github.com/JustAnotherArchivist/snscrape.git # developer version for more attribute like reply count
pip install langdetect # filter english language tweets from csv
pip install ipynb # to use another .ipynb file
pip install patsy # for nb
pip install emoji # for emoji
pip install textstat # for flesch score

# %% [markdown]
# # Import libraries

# %%
from textblob import TextBlob
import tweepy
import sys
import snscrape.modules.twitter as sntwitter
import csv
import pandas as pd
import re
import nltk
import string
from nltk.stem import PorterStemmer
from langdetect import detect
from ipynb.fs.full.stop_words import stopwords
from sklearn.utils import shuffle
import numpy as np
import matplotlib.pyplot as plt
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import emoji
import textstat
from gensim import corpora
import gensim
from wordcloud import WordCloud
from patsy import dmatrices
import statsmodels.api as sm
import statsmodels.formula.api as smf
from textstat.textstat import textstatistics, legacy_round
import pickle

# %% [markdown]
# # Twitter authorization

# %%
mykeys = open('twitter_keys.txt', 'r').read().splitlines()

# Twitter API credentials
api_keys = mykeys[0]
api_secret_key = mykeys[1]
access_token = mykeys[2]
access_token_secret = mykeys[3]

# create authentication 
auth = tweepy.OAuthHandler(consumer_key=api_keys, consumer_secret = api_secret_key)

# set access token and access toekn secret
auth.set_access_token(access_token, access_token_secret)

# creat eaPI object while passing in the auth information
api = tweepy.API(auth, wait_on_rate_limit = True)

# %% [markdown]
# # Check Twitter connection

# %%
# extract 100 tweets from twitter user
posts = api.user_timeline(screen_name = 'JoeBiden', count = 125, lang = 'en', tweet_mode = 'extended')
print('show 5 recent tweets \n')
for tweet in posts[0:50]:
    print(tweet.full_text + '\n')

# %% [markdown]
# # Extract Tweets, no. of likes, retweets and comments

# %%
maxTweets = 1000

# create csv file
csvBiden = open('JoeBiden.csv', 'a', newline='', encoding='utf8')
csvTrump = open('Trump.csv', 'a', newline='', encoding='utf8')

# write in created csv files
csvWriterBiden = csv.writer(csvBiden)
csvWriterBiden.writerow(['ID', 'Date', 'Tweet', 'Reply_count', 'Retweet_count', 'Like_count'])

csvWriterTrump = csv.writer(csvTrump)
csvWriterTrump.writerow(['ID', 'Date', 'Tweet', 'Reply_count', 'Retweet_count', 'Like_count'])

# tweets from september to november 2020
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:@JoeBiden + since:2020-9-03 until:2020-11-03').get_items()):
    if i > maxTweets:
        break
    csvWriterBiden.writerow([tweet.id, tweet.date, tweet.content, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:@WhiteHouse45 + since:2020-9-03 until:2020-11-03').get_items()):
    if i > maxTweets:
        break
    csvWriterTrump.writerow([tweet.id, tweet.date, tweet.content, tweet.replyCount, tweet.retweetCount, tweet.likeCount])
    
# close csv files
csvBiden.close()
csvTrump.close()

# %% [markdown]
# # Data Cleaning

# %%
# Open file
dftrump = pd.read_csv('Trump.csv')

# merge both csv files
all_tweets = dftrump

# check top 5 rows and column names and shape
# all_tweets.head()
# all_tweets.columns
all_tweets.shape

# check duplicate tweets
# all_tweets.tweet.unique()

# check 0 values in counts
# all_tweets.isna().sum()
# Out:
# (936, 6)

# %%
# remove non english tweets
def detect_lang(text):
    try:
        return detect(text) == 'en'
    except:
        return False

all_tweets = all_tweets[all_tweets['Tweet'].apply(detect_lang)]

# %%
# remove links
all_tweets['Tweet'] = all_tweets['Tweet'].replace(to_replace=r'https?:\/\/.*[\r\n\s]*',value='',regex=True)
# Out:
# <ipython-input-4-f59ea6545fa9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_tweets['Tweet'] = all_tweets['Tweet'].replace(to_replace=r'https?:\/\/.*[\r\n\s]*',value='',regex=True)

# %%
# check number of rows after removing non English tweets
all_tweets.shape
# Out:
# (914, 6)

# %%
# remove usernames
all_tweets['Tweet'] = all_tweets['Tweet'].apply(lambda x: ' '.join(re.sub("(@[A-Za-z0-9]+)", "", x).split()))
# Out:
# <ipython-input-6-b4c98fbfd5b7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_tweets['Tweet'] = all_tweets['Tweet'].apply(lambda x: ' '.join(re.sub("(@[A-Za-z0-9]+)", "", x).split()))

# %%
def strip_emoji(text):
    new_text = re.sub(emoji.get_emoji_regexp(), r"", text)
    return new_text

all_tweets['Tweet'] = all_tweets['Tweet'].apply(lambda x: strip_emoji(x))
# Out:
# <ipython-input-7-b90f761c39db>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_tweets['Tweet'] = all_tweets['Tweet'].apply(lambda x: strip_emoji(x))

# %%
all_tweets.describe()
# Out:
#                  ID   Reply_count  Retweet_count    Like_count
# count  9.140000e+02    914.000000     914.000000    914.000000
# mean   1.312314e+18    823.458425     971.310722   4553.881838
# std    6.771670e+15   1080.762276     974.569144   4424.462646
# min    1.301328e+18     25.000000     153.000000    730.000000
# 25%    1.306307e+18    320.250000     427.250000   1982.000000
# 50%    1.310673e+18    532.000000     679.000000   3308.500000
# 75%    1.318715e+18    934.250000    1102.500000   5142.750000
# max    1.323406e+18  14638.000000    9944.000000  43596.000000

# %% [markdown]
# # Measure sophistication words

# %% [markdown]
# ###### Designed to indicate how difficult a reading passage is to understand. Higher scores indicate material that is easier to read; lower numbers mark harder-to-read passages.
#
# FRE = 206.835 − 1.015*(total words/
# total sentences) − 84.6 * (total
# syllables/ total words)
# Used this article https://www.kaggle.com/fshenbayh/readability

# %%
all_tweets['FRE'] = all_tweets['Tweet'].apply(lambda x: textstat.flesch_reading_ease(x))
all_tweets['FRE']
# Out:
# <ipython-input-9-f0cc9d24a15b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_tweets['FRE'] = all_tweets['Tweet'].apply(lambda x: textstat.flesch_reading_ease(x))
# 0      74.19
# 1      69.62
# 2      80.28
# 3      63.19
# 4      68.60
#        ...
# 931    92.80
# 932    67.76
# 933    75.71
# 934    81.63
# 935    49.83
# Name: FRE, Length: 914, dtype: float64

# %%
# histogram for Flesch score
flesch_score = all_tweets.hist(column='FRE', bins='auto', color='#0504aa',
                            grid=False, figsize=(12,8), zorder=2, rwidth=0.9)
plt.xlabel('Flesch Score')
plt.ylabel('Frequency')
plt.title('Histogram of Flesch Score of tweets')
# Out:
# Text(0.5, 1.0, 'Histogram of Flesch Score of tweets')

# %%
# remove punctuations and replace special words with '_'
all_tweets['Tweet'] = all_tweets['Tweet'].str.replace(r"[\’\']", '_')
all_tweets['Tweet'] = all_tweets['Tweet'].str.replace(r"[\‘\“\”\"\``\''\`\”\...\“—–]", '')

all_tweets
# Out:
# <ipython-input-11-33c63140bcf0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_tweets['Tweet'] = all_tweets['Tweet'].str.replace(r"[\’\']", '_')
# <ipython-input-11-33c63140bcf0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_tweets['Tweet'] = all_tweets['Tweet'].str.replace(r"[\‘\“\”\"\``\''\`\”\...\“—–]", '')
#                       ID                       Date  \
# 0    1323406093930893313  2020-11-02 23:26:15+00:00
# 1    1323394549885161474  2020-11-02 22:40:22+00:00
# 2    1323386990478401539  2020-11-02 22:10:20+00:00
# 3    1323369908017766401  2020-11-02 21:02:27+00:00
# 4    1323368754965864449  2020-11-02 20:57:52+00:00
# ..                   ...                        ...
# 931  1301568587908280322  2020-09-03 17:11:47+00:00
# 932  1301533937613799426  2020-09-03 14:54:06+00:00
# 933  1301530918751006720  2020-09-03 14:42:06+00:00
# 934  1301528549040496640  2020-09-03 14:32:41+00:00
# 935  1301328055932268546  2020-09-03 01:16:00+00:00
#
#                                                  Tweet  Reply_count  \
# 0    In 2019, the official poverty rate fell to an ...         1320
# 1    No recent President has done more than Preside...          592
# 2    On President Trump_s watch, peacenot waris bre...         1094
# 3    In October, President brokered a peace agreeme...          831
# 4    Before this summer, only two peace deals betwe...          469
# ..                                                 ...          ...
# 931                             LIVE: holds a briefing         2226
# 932  One set of rules for Nancy Pelosi, another for...         2949
# 933  It_s not often you hear a governor describe in...         1053
# 934  The Democrat mayors of Chicago, Portland, and ...          950
# 935  Today marks the 75th anniversary of the end of...          470
#
#      Retweet_count  Like_count    FRE
# 0             1066        4808  74.19
# 1              467        2611  69.62
# 2             1331        6281  80.28
# 3              962        5430  63.19
# 4              636        3281  68.60
# ..             ...         ...    ...
# 931           1934        6435  92.80
# 932           1994        7227  67.76
# 933           1908        5443  75.71
# 934            906        3292  81.63
# 935            910        4025  49.83
#
# [914 rows x 7 columns]

# %% [markdown]
# # Sentiment analysis

# %%
# create new columns for polarity, compound and sentiment
analyzer = SentimentIntensityAnalyzer()

for index, text in all_tweets['Tweet'].iteritems():
    senti = analyzer.polarity_scores(text)
    neg = senti['neg']
    pos = senti['pos']
    neu = senti['neu']
    comp = senti['compound']
    
    if neg > pos:
        all_tweets.loc[index, 'Sentiment'] = 'Negative'
    elif neg < pos:
        all_tweets.loc[index, 'Sentiment'] = 'Positive'
    else:
        all_tweets.loc[index, 'Sentiment'] = 'Neutral'
        
    all_tweets.loc[index, 'Neg_pol'] = neg
    all_tweets.loc[index, 'Pos_pol'] = pos
    all_tweets.loc[index, 'Neu_pol'] = neu
    all_tweets.loc[index, 'Compound'] = comp
    
all_tweets
# Out:
# C:\Users\priya\anaconda3\lib\site-packages\pandas\core\indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\priya\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#                       ID                       Date  \
# 0    1323406093930893313  2020-11-02 23:26:15+00:00
# 1    1323394549885161474  2020-11-02 22:40:22+00:00
# 2    1323386990478401539  2020-11-02 22:10:20+00:00
# 3    1323369908017766401  2020-11-02 21:02:27+00:00
# 4    1323368754965864449  2020-11-02 20:57:52+00:00
# ..                   ...                        ...
# 931  1301568587908280322  2020-09-03 17:11:47+00:00
# 932  1301533937613799426  2020-09-03 14:54:06+00:00
# 933  1301530918751006720  2020-09-03 14:42:06+00:00
# 934  1301528549040496640  2020-09-03 14:32:41+00:00
# 935  1301328055932268546  2020-09-03 01:16:00+00:00
#
#                                                  Tweet  Reply_count  \
# 0    In 2019, the official poverty rate fell to an ...         1320
# 1    No recent President has done more than Preside...          592
# 2    On President Trump_s watch, peacenot waris bre...         1094
# 3    In October, President brokered a peace agreeme...          831
# 4    Before this summer, only two peace deals betwe...          469
# ..                                                 ...          ...
# 931                             LIVE: holds a briefing         2226
# 932  One set of rules for Nancy Pelosi, another for...         2949
# 933  It_s not often you hear a governor describe in...         1053
# 934  The Democrat mayors of Chicago, Portland, and ...          950
# 935  Today marks the 75th anniversary of the end of...          470
#
#      Retweet_count  Like_count    FRE Sentiment  Neg_pol  Pos_pol  Neu_pol  \
# 0             1066        4808  74.19  Negative    0.240    0.000    0.760
# 1              467        2611  69.62  Positive    0.055    0.072    0.873
# 2             1331        6281  80.28   Neutral    0.000    0.000    1.000
# 3              962        5430  63.19  Positive    0.000    0.361    0.639
# 4              636        3281  68.60  Positive    0.000    0.234    0.766
# ..             ...         ...    ...       ...      ...      ...      ...
# 931           1934        6435  92.80   Neutral    0.000    0.000    1.000
# 932           1994        7227  67.76   Neutral    0.000    0.000    1.000
# 933           1908        5443  75.71  Negative    0.064    0.000    0.936
# 934            906        3292  81.63  Positive    0.118    0.224    0.658
# 935            910        4025  49.83  Positive    0.000    0.215    0.785
#
#      Compound
# 0     -0.9001
# 1      0.1779
# 2      0.0000
# 3      0.9415
# 4      0.8750
# ..        ...
# 931    0.0000
# 932    0.0000
# 933   -0.1655
# 934    0.6124
# 935    0.8625
#
# [914 rows x 12 columns]

# %%
# calculate percentage of polarity
def cal_percentage(data,feature):
    perce = round(data.loc[:,feature].value_counts(dropna=False, normalize=True)*100,2)
    return perce

pie = cal_percentage(all_tweets,'Sentiment')

# %%
# create pie chart of polarity
pie_pd = pd.DataFrame(pie)

my_labels = 'Positive','Neutral','Negative'
plt.pie(pie_pd['Sentiment'], autopct='%1.1f%%', startangle = 90)
plt.title('Sentiment Analysis')
plt.axis('equal')
plt.legend(my_labels, loc="best")
plt.show()

# %% [markdown]
# # Length of the tweets (number of words)

# %%
# word tokenization
all_tweets['Tweet'] = all_tweets['Tweet'].apply(nltk.word_tokenize)
# Out:
# <ipython-input-15-28476a1c62f2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_tweets['Tweet'] = all_tweets['Tweet'].apply(nltk.word_tokenize)

# %%
# remove stopwords
stopwordlist = stopwords()
all_tweets['Tweet'] = all_tweets['Tweet'].apply(lambda x: list(set([text.lower() for text in x 
                                   if text.lower() not in stopwordlist and text.lower() not in string.punctuation])))
# Out:
# <ipython-input-16-81817ad21f44>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_tweets['Tweet'] = all_tweets['Tweet'].apply(lambda x: list(set([text.lower() for text in x

# %%
# stemming
stemmer = PorterStemmer()
all_tweets['Tweet'].apply(lambda w: [stemmer.stem(t) for t in w])
# Out:
# 0      [all-tim, percent, low, record, million, offic...
# 1      [robb, recent, econom, job, west, confirm, sin...
# 2                 [watch, peacenot, wari, presid, break]
# 3      [arab-muslim, agreement, sudan, world, peac, r...
# 4      [announc, arab, year, neighbor, secur, help, m...
#                              ...
# 931                                  [brief, hold, live]
# 932                 [pelosi, nanci, american, rule, set]
# 933    [lost, cuomo, governor, vivid, control, state,...
# 934    [abil, hour, feder, help, democrat, refus, pea...
# 935    [daili, past, hero, cherish, presid, end, 75th...
# Name: Tweet, Length: 914, dtype: object

# %%
# create new column for number of words in tweets
all_tweets['Tweet_length'] = all_tweets['Tweet'].apply(lambda x: len(x))
# Out:
# <ipython-input-24-07f16ec6c0be>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_tweets['Tweet_length'] = all_tweets['Tweet'].apply(lambda x: len(x))

# %%
# get all columns stats information
all_tweets.describe()
# Out:
#                  ID   Reply_count  Retweet_count    Like_count         FRE  \
# count  9.140000e+02    914.000000     914.000000    914.000000  914.000000
# mean   1.312314e+18    823.458425     971.310722   4553.881838   49.113807
# std    6.771670e+15   1080.762276     974.569144   4424.462646   20.187580
# min    1.301328e+18     25.000000     153.000000    730.000000  -28.700000
# 25%    1.306307e+18    320.250000     427.250000   1982.000000   36.280000
# 50%    1.310673e+18    532.000000     679.000000   3308.500000   49.820000
# 75%    1.318715e+18    934.250000    1102.500000   5142.750000   61.660000
# max    1.323406e+18  14638.000000    9944.000000  43596.000000  112.090000
#
#           Neg_pol     Pos_pol    Neu_pol    Compound  Tweet_length
# count  914.000000  914.000000  914.00000  914.000000    914.000000
# mean     0.048588    0.152816    0.79860    0.312071     13.068928
# std      0.084613    0.129808    0.14274    0.483955      5.586780
# min      0.000000    0.000000    0.20000   -0.955200      0.000000
# 25%      0.000000    0.000000    0.69450    0.000000      9.000000
# 50%      0.000000    0.148000    0.79700    0.438900     13.000000
# 75%      0.077750    0.236750    0.90800    0.734500     17.000000
# max      0.456000    0.800000    1.00000    0.979300     29.000000

# %%
# histogram for number of words in tweets
number_words = all_tweets.hist(column='Tweet_length', bins='auto', color='#0504aa',
                            grid=False, figsize=(12,8), zorder=2, rwidth=0.9)
plt.xlabel('Tweet_length')
plt.ylabel('Frequency')
plt.title('Histogram of number of words in tweets')
# Out:
# Text(0.5, 1.0, 'Histogram of number of words in tweets')

# %% [markdown]
# # Hourly tweets

# %%
# we can convert date column in datetime formate using to_datetime and split time but not able to groupby 
# split date column in time
time = [item.split(" ")[1] for item in all_tweets['Date'].values] 

# take only hours from time
hour = [item.split(":")[0] for item in time]
all_tweets['Tweet_time'] = hour

# groupby hour and count number of tweets 
all_tweets_time = all_tweets.groupby(['Tweet_time']).size().reset_index(name='Number_tweets')
all_tweets_time
# Out:
# <ipython-input-27-0b4153e6ae81>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_tweets['Tweet_time'] = hour
#    Tweet_time  Number_tweets
# 0          00             72
# 1          01             35
# 2          02              5
# 3          03              1
# 4          04              6
# 5          12              3
# 6          13              9
# 7          14             50
# 8          15             63
# 9          16             69
# 10         17             80
# 11         18             96
# 12         19             95
# 13         20             91
# 14         21             95
# 15         22             78
# 16         23             66

# %%
# create bar plot 
tweet_hours = all_tweets_time.reset_index().plot(x = 'Tweet_time', y = 'Number_tweets', kind ='bar')
plt.xlabel('Tweet_time')
plt.ylabel('Number_tweets')
plt.title('Histogram of tweet time')
# Out:
# Text(0.5, 1.0, 'Histogram of tweet time')

# %% [markdown]
# # Lexicon sentiment analysis

# %%
# remove rows which has 0 words in tweets
all_tweets = all_tweets[all_tweets['Tweet_length'] != 0]
all_tweets.shape
# Out:
# (911, 14)

# %%
strong = open('strong.txt', 'r')
weak = open('weak.txt', 'r')
hostile = open('hostile.txt', 'r')
pleasure = open('pleasure.txt', 'r')

strongwordlist = [x.lower().strip('\n') for x in strong]
weakwordlist = [x.lower().strip('\n') for x in weak]
hostilewordlist = [x.lower().strip('\n') for x in hostile]
pleasurewordlist = [x.lower().strip('\n') for x in pleasure]
      
all_tweets['Strong'] = all_tweets['Tweet'].apply(lambda x: sum([1 if word in strongwordlist else 0 for word in x])/len(x))
all_tweets['Weak'] = all_tweets['Tweet'].apply(lambda x: sum([1 if word in weakwordlist else 0 for word in x])/len(x))
all_tweets['Hostile'] = all_tweets['Tweet'].apply(lambda x: sum([1 if word in hostilewordlist else 0 for word in x])/len(x))
all_tweets['Pleasure'] = all_tweets['Tweet'].apply(lambda x: sum([1 if word in pleasurewordlist else 0 for word in x])/len(x))

all_tweets
# Out:
# <ipython-input-30-cd6e66cf7cbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_tweets['Strong'] = all_tweets['Tweet'].apply(lambda x: sum([1 if word in strongwordlist else 0 for word in x])/len(x))
# <ipython-input-30-cd6e66cf7cbc>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_tweets['Weak'] = all_tweets['Tweet'].apply(lambda x: sum([1 if word in weakwordlist else 0 for word in x])/len(x))
# <ipython-input-30-cd6e66cf7cbc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_tweets['Hostile'] = all_tweets['Tweet'].apply(lambda x: sum([1 if word in hostilewordlist else 0 for word in x])/len(x))
# <ipython-input-30-cd6e66cf7cbc>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_tweets['Pleasure'] = all_tweets['Tweet'].apply(lambda x: sum([1 if word in pleasurewordlist else 0 for word in x])/len(x))
#                       ID                       Date  \
# 0    1323406093930893313  2020-11-02 23:26:15+00:00
# 1    1323394549885161474  2020-11-02 22:40:22+00:00
# 2    1323386990478401539  2020-11-02 22:10:20+00:00
# 3    1323369908017766401  2020-11-02 21:02:27+00:00
# 4    1323368754965864449  2020-11-02 20:57:52+00:00
# ..                   ...                        ...
# 931  1301568587908280322  2020-09-03 17:11:47+00:00
# 932  1301533937613799426  2020-09-03 14:54:06+00:00
# 933  1301530918751006720  2020-09-03 14:42:06+00:00
# 934  1301528549040496640  2020-09-03 14:32:41+00:00
# 935  1301328055932268546  2020-09-03 01:16:00+00:00
#
#                                                  Tweet  Reply_count  \
# 0    [all-time, percent, low, record, million, offi...         1320
# 1    [robb, recent, economic, job, west, confirm, s...          592
# 2        [watch, peacenot, waris, president, breaking]         1094
# 3    [arab-muslim, agreement, sudan, world, peace, ...          831
# 4    [announced, arab, year, neighbors, secured, he...          469
# ..                                                 ...          ...
# 931                            [briefing, holds, live]         2226
# 932              [pelosi, nancy, american, rules, set]         2949
# 933  [lost, cuomo, governor, vivid, control, state,...         1053
# 934  [ability, hours, federal, help, democrat, refu...          950
# 935  [daily, past, heroes, cherish, president, end,...          470
#
#      Retweet_count  Like_count    FRE Sentiment  Neg_pol  Pos_pol  Neu_pol  \
# 0             1066        4808  74.19  Negative    0.240    0.000    0.760
# 1              467        2611  69.62  Positive    0.055    0.072    0.873
# 2             1331        6281  80.28   Neutral    0.000    0.000    1.000
# 3              962        5430  63.19  Positive    0.000    0.361    0.639
# 4              636        3281  68.60  Positive    0.000    0.234    0.766
# ..             ...         ...    ...       ...      ...      ...      ...
# 931           1934        6435  92.80   Neutral    0.000    0.000    1.000
# 932           1994        7227  67.76   Neutral    0.000    0.000    1.000
# 933           1908        5443  75.71  Negative    0.064    0.000    0.936
# 934            906        3292  81.63  Positive    0.118    0.224    0.658
# 935            910        4025  49.83  Positive    0.000    0.215    0.785
#
#      Compound  Tweet_length Tweet_time    Strong      Weak  Hostile  Pleasure
# 0     -0.9001            19         23  0.000000  0.105263      0.0  0.000000
# 1      0.1779            18         22  0.055556  0.000000      0.0  0.000000
# 2      0.0000             5         22  0.200000  0.000000      0.0  0.000000
# 3      0.9415            13         21  0.153846  0.000000      0.0  0.000000
# 4      0.8750            16         20  0.062500  0.000000      0.0  0.000000
# ..        ...           ...        ...       ...       ...      ...       ...
# 931    0.0000             3         17  0.000000  0.000000      0.0  0.000000
# 932    0.0000             5         14  0.000000  0.000000      0.0  0.000000
# 933   -0.1655             7         14  0.285714  0.000000      0.0  0.000000
# 934    0.6124            16         14  0.062500  0.000000      0.0  0.000000
# 935    0.8625            19         01  0.105263  0.000000      0.0  0.052632
#
# [911 rows x 18 columns]

# %% [markdown]
# # Topic Modelling

# %% [markdown]
# ###### Refered this article https://towardsdatascience.com/lda-topic-modeling-with-tweets-deff37c0e131
# ###### https://towardsdatascience.com/twitter-topic-modeling-e0e3315b12e2

# %%
# step 1: 
# iterate through each tweet, then each token in each tweet
flat_words = [item for sublist in all_tweets['Tweet'] for item in sublist]
word_freq = nltk.FreqDist(flat_words).most_common(10)
common_words = [w[0] for w in word_freq]
# print(common_words)

# remove most common words
for tweetlist in all_tweets['Tweet']:
    for t in tweetlist:
        if t in common_words:
            tweetlist.remove(t)

# check most common words after removing
rm_common_words = [wrds for sblst in all_tweets['Tweet'] for wrds in sblst]
wordlist = nltk.FreqDist(rm_common_words)
# print(wordlist)

# %%
#retrieve word and count from FreqDist tuples
most_common_count = [x[1] for x in wordlist.most_common(100)]
most_common_word = [x[0] for x in wordlist.most_common(100)]

#create dictionary mapping of word count
top_30_dictionary = dict(zip(most_common_word, most_common_count))

# %%
wc = WordCloud(colormap = 'Accent', background_color = 'white').generate_from_frequencies(top_30_dictionary)
plt.imshow(wc, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
# Step 2: generating dictionary
token_id = corpora.Dictionary(all_tweets.Tweet) # this is all words. All the words appearing in all the documents
token_id.token2id
# Out:
# {'105': 0,
#  '13': 1,
#  '2018-2019': 2,
#  '2019': 3,
#  '4': 4,
#  '50': 5,
#  'all-time': 6,
#  'decrease': 7,
#  'fell': 8,
#  'largest': 9,
#  'lifted': 10,
#  'low': 11,
#  'official': 12,
#  'percent': 13,
#  'poverty': 14,
#  'rate': 15,
#  'record': 16,
#  'reduction': 17,
#  'blue-collar': 18,
#  'confirm': 19,
#  'data': 20,
#  'economic': 21,
#  'improve': 22,
#  'job': 23,
#  'lives': 24,
#  'reads': 25,
#  'recent': 26,
#  'robb': 27,
#  'sinn': 28,
#  'third-quarter': 29,
#  'west': 30,
#  'wing': 31,
#  'writes': 32,
#  'breaking': 33,
#  'peacenot': 34,
#  'waris': 35,
#  'watch': 36,
#  'agreement': 37,
#  'arab-muslim': 38,
#  'brokered': 39,
#  'israel': 40,
#  'israelthe': 41,
#  'months': 42,
#  'nation': 43,
#  'october': 44,
#  'peace': 45,
#  'reach': 46,
#  'sudan': 47,
#  'world': 48,
#  '72': 49,
#  'agreements': 50,
#  'announced': 51,
#  'arab': 52,
#  'deals': 53,
#  'help': 54,
#  'historic': 55,
#  'month': 56,
#  'neighbors': 57,
#  'past': 58,
#  'secured': 59,
#  'summer': 60,
#  'year': 61,
#  'allies': 62,
#  'caliphate': 63,
#  'cash': 64,
#  'dead': 65,
#  'destroyed': 66,
#  'east': 67,
#  'endless': 68,
#  'fight': 69,
#  'giving': 70,
#  'instead': 71,
#  'iran': 72,
#  'isis': 73,
#  'leaders': 74,
#  'middle': 75,
#  'real': 76,
#  'securing': 77,
#  'sending': 78,
#  'sponsors': 79,
#  'states': 80,
#  'terrorist': 81,
#  'troops': 82,
#  'wars': 83,
#  'military': 84,
#  'stronger': 85,
#  'cold': 86,
#  'country': 87,
#  'foreign': 88,
#  'helped': 89,
#  'leader': 90,
#  'policy': 91,
#  'reagan': 92,
#  'rebuilt': 93,
#  'renewed': 94,
#  'restored': 95,
#  'ronald': 96,
#  'sovereignty': 97,
#  'start': 98,
#  'strength': 99,
#  'war': 100,
#  'win': 101,
#  '1961': 102,
#  'bay': 103,
#  'communism': 104,
#  'cuban': 105,
#  'fall': 106,
#  'forces': 107,
#  'freedom': 108,
#  'honored': 109,
#  'house': 110,
#  'invasion': 111,
#  'patriots': 112,
#  'pigs': 113,
#  'prevail': 114,
#  'sinister': 115,
#  'socialism': 116,
#  'white': 117,
#  'brutal': 118,
#  'cuba': 119,
#  'denying': 120,
#  'dictatorships': 121,
#  'direct': 122,
#  'funds': 123,
#  'latin': 124,
#  'national': 125,
#  'nicaragua': 126,
#  'president': 127,
#  'security': 128,
#  'supporting': 129,
#  'threat': 130,
#  'venezuela': 131,
#  'achieved': 132,
#  'community': 133,
#  'creating': 134,
#  'environment': 135,
#  'hispanic': 136,
#  'promise': 137,
#  'record-setting': 138,
#  'result': 139,
#  'successes': 140,
#  'thriving': 141,
#  '55': 142,
#  'committed': 143,
#  'direction': 144,
#  'everglades': 145,
#  'florida_s': 146,
#  'funding': 147,
#  'increased': 148,
#  'protect': 149,
#  'protecting': 150,
#  'restoring': 151,
#  'wetlands': 152,
#  '24,000': 153,
#  'america_s': 154,
#  'dominance': 155,
#  'final': 156,
#  'florida': 157,
#  'frontier': 158,
#  'invested': 159,
#  'jobs': 160,
#  'previous': 161,
#  'restore': 162,
#  'space': 163,
#  'status': 164,
#  'supports': 165,
#  'surrendered': 166,
#  'aerospace': 167,
#  'booming': 168,
#  'budget': 169,
#  'create': 170,
#  'defense': 171,
#  'example': 172,
#  'floridaand': 173,
#  'greater': 174,
#  'helping': 175,
#  'increases': 176,
#  'industry': 177,
#  'level': 178,
#  'local': 179,
#  '3': 180,
#  'communities': 181,
#  'covid': 182,
#  'georgia': 183,
#  'point-of-care': 184,
#  'rapid': 185,
#  'receiving': 186,
#  'support': 187,
#  'tests': 188,
#  'doctors': 189,
#  'en': 190,
#  'georgia_s': 191,
#  'nurses': 192,
#  'responders': 193,
#  'route': 194,
#  'thank': 195,
#  'action': 196,
#  'black-owned': 197,
#  'businesses': 198,
#  'comeback': 199,
#  'incredible': 200,
#  'leading': 201,
#  'numbers': 202,
#  'pre-pandemic': 203,
#  'rebound': 204,
#  'recovery': 205,
#  'way': 206,
#  'carolina': 207,
#  'celebrate': 208,
#  'farmers': 209,
#  'manufacturers': 210,
#  'negotiations': 211,
#  'north': 212,
#  'policies': 213,
#  'pro-industry': 214,
#  'reason': 215,
#  'scientists': 216,
#  'thanks': 217,
#  'tough': 218,
#  'trade': 219,
#  'benefits': 220,
#  'boosting': 221,
#  'business': 222,
#  'cuts': 223,
#  'family': 224,
#  'friendly': 225,
#  'friendlyresulting': 226,
#  'higher': 227,
#  'income': 228,
#  'opportunity': 229,
#  'tax': 230,
#  'wages': 231,
#  'zones': 232,
#  '3,150,000': 233,
#  'directly': 234,
#  'facilities': 235,
#  'half': 236,
#  'high-priority': 237,
#  'sent': 238,
#  'heading': 239,
#  'actions': 240,
#  'alikeand': 241,
#  'boxes': 242,
#  'dairy': 243,
#  'families': 244,
#  'food': 245,
#  'fourth': 246,
#  'helps': 247,
#  'leadership': 248,
#  'meat': 249,
#  'president_s': 250,
#  'produce': 251,
#  'purchase': 252,
#  'round': 253,
#  'suppliers': 254,
#  'surplus': 255,
#  'underway': 256,
#  'energy': 257,
#  'ethanol': 258,
#  'imposed': 259,
#  'producers': 260,
#  'radical': 261,
#  'rejected': 262,
#  'restrictions': 263,
#  'stand': 264,
#  '3,100': 265,
#  'average': 266,
#  'change': 267,
#  'double': 268,
#  'grow': 269,
#  'iowa': 270,
#  'nearly': 271,
#  'saw': 272,
#  '950,000': 273,
#  'covid-19': 274,
#  'stop': 275,
#  'black': 276,
#  'breakthroughs': 277,
#  'criminal': 278,
#  'decades': 279,
#  'delivered': 280,
#  'incarcerated': 281,
#  'justice': 282,
#  'lowest': 283,
#  'number': 284,
#  'officethe': 285,
#  'trumpwho': 286,
#  'autoworkers': 287,
#  'boost': 288,
#  'michigan_s': 289,
#  'caregivers': 290,
#  'michigan': 291,
#  'morning': 292,
#  '331': 293,
#  'gdp': 294,
#  'growth': 295,
#  'highest': 296,
#  'quarter': 297,
#  'lost': 298,
#  'output': 299,
#  'pandemic': 300,
#  'recovered': 301,
#  'single': 302,
#  'two-thirds': 303,
#  '1': 304,
#  '10': 305,
#  '2': 306,
#  'abandons': 307,
#  'dirty': 308,
#  'evaporate': 309,
#  'extremist': 310,
#  'important': 311,
#  'oil': 312,
#  'overseas': 313,
#  'piece': 314,
#  'politicians': 315,
#  'production': 316,
#  'ship': 317,
#  'suffer': 318,
#  'believe': 319,
#  'impunity': 320,
#  'kidnap': 321,
#  'mistakenly': 322,
#  'operation': 323,
#  'serve': 324,
#  'stark': 325,
#  'terrorists': 326,
#  'thugs': 327,
#  'warning': 328,
#  '24': 329,
#  'abroad': 330,
#  'beginning': 331,
#  'captivity': 332,
#  'countries': 333,
#  'detainees': 334,
#  'held': 335,
#  'hostages': 336,
#  'priority': 337,
#  'rescued': 338,
#  'bravery': 339,
#  'currently': 340,
#  'daring': 341,
#  'exceptional': 342,
#  'executed': 343,
#  'fellow': 344,
#  'good': 345,
#  'harmed': 346,
#  'health': 347,
#  'hostage': 348,
#  'members': 349,
#  'nighttime': 350,
#  'precision': 351,
#  'rescue': 352,
#  'reunited': 353,
#  'service': 354,
#  'skill': 355,
#  'special': 356,
#  '96': 357,
#  'conducted': 358,
#  'earlier': 359,
#  'hours': 360,
#  'kidnapped': 361,
#  'nigeria': 362,
#  'night': 363,
#  'successful': 364,
#  'american': 365,
#  'dream': 366,
#  '40': 367,
#  '66': 368,
#  'asian': 369,
#  'fastest': 370,
#  'hit': 371,
#  'households': 372,
#  'increase': 373,
#  'lows': 374,
#  'net': 375,
#  'rose': 376,
#  'unemployment': 377,
#  'worth': 378,
#  'behindincluding': 379,
#  'economy': 380,
#  'grew': 381,
#  'history': 382,
#  'incomes': 383,
#  'left': 384,
#  'rates': 385,
#  'record-high': 386,
#  'record-low': 387,
#  'strongest': 388,
#  'believes': 389,
#  'bureaucrats': 390,
#  'dollars': 391,
#  'hard-earned': 392,
#  'home': 393,
#  'money': 394,
#  'spent': 395,
#  'taken': 396,
#  'wasteful': 397,
#  'accountable': 398,
#  'arsonists': 399,
#  'brave': 400,
#  'brought': 401,
#  'country_s': 402,
#  'defund': 403,
#  'enforcement': 404,
#  'law': 405,
#  'looters': 406,
#  'officers': 407,
#  'peaceful': 408,
#  'police': 409,
#  'policing': 410,
#  'protected': 411,
#  'protesters': 412,
#  'rioters': 413,
#  'safer': 414,
#  '30': 415,
#  '33': 416,
#  'bricks': 417,
#  'city': 418,
#  'council': 419,
#  'injuries': 420,
#  'reduced': 421,
#  'stones': 422,
#  'sustained': 423,
#  'threw': 424,
#  'unrest': 425,
#  'dependence': 426,
#  'edge': 427,
#  'finally': 428,
#  'gained': 429,
#  'impacts': 430,
#  'independence': 431,
#  'nations': 432,
#  'supplies': 433,
#  '38': 434,
#  'election': 435,
#  'gas': 436,
#  'natural': 437,
#  'pennsylvania': 438,
#  'producing': 439,
#  'second': 440,
#  'state': 441,
#  'usa': 442,
#  '17,000': 443,
#  '9,000': 444,
#  'created': 445,
#  'expansion': 446,
#  'global': 447,
#  'manufacturing': 448,
#  'pa': 449,
#  'period': 450,
#  'prior': 451,
#  '3,850,000': 452,
#  'pennsylvania_s': 453,
#  'halloween': 454,
#  'happy': 455,
#  'blue': 456,
#  'boom': 457,
#  'collar': 458,
#  'deregulations': 459,
#  'goal': 460,
#  'ignited': 461,
#  'kept': 462,
#  'lift': 463,
#  'old': 464,
#  'outperformed': 465,
#  'promises': 466,
#  'regulations': 467,
#  'regulatory': 468,
#  'removing': 469,
#  'seven': 470,
#  '-made': 471,
#  'craftsmen': 472,
#  'engineers': 473,
#  'factory': 474,
#  'goods': 475,
#  'sold': 476,
#  'standing': 477,
#  'affluent': 478,
#  'agenda': 479,
#  'class': 480,
#  'failure': 481,
#  'globalization': 482,
#  'power': 483,
#  'professionals': 484,
#  'rebuild': 485,
#  'tailor-made': 486,
#  'transferring': 487,
#  'white-collar': 488,
#  '10th': 489,
#  '90th': 490,
#  'americansthose': 491,
#  'distributionhas': 492,
#  'high': 493,
#  'household': 494,
#  'lower-income': 495,
#  'outpaced': 496,
#  'percentile': 497,
#  'wage': 498,
#  'wealthier': 499,
#  'bachelor_s': 500,
#  'degree': 501,
#  'managers': 502,
#  'workers': 503,
#  '1984': 504,
#  'deregulation': 505,
#  'expanding': 506,
#  'markets': 507,
#  'medical': 508,
#  'miners': 509,
#  'minnesota': 510,
#  'pro-job': 511,
#  'products': 512,
#  'usmca': 513,
#  'working': 514,
#  'capital': 515,
#  'disaster': 516,
#  'farms': 517,
#  'improved': 518,
#  'nafta': 519,
#  'nationwide': 520,
#  'renegotiated': 521,
#  'replaced': 522,
#  'wisconsin': 523,
#  'citizen': 524,
#  'deal': 525,
#  'deserved': 526,
#  'knew': 527,
#  'private': 528,
#  '1,750,000': 529,
#  'wisconsin_s': 530,
#  'day': 531,
#  'epic': 532,
#  'industries': 533,
#  'men': 534,
#  'proving': 535,
#  'reopeningand': 536,
#  'safe': 537,
#  'women': 538,
#  'kits': 539,
#  'test': 540,
#  'essential': 541,
#  'frontline': 542,
#  'looking': 543,
#  'millions': 544,
#  'ppe': 545,
#  'workerssending': 546,
#  'got': 547,
#  'making': 548,
#  'pro-growth': 549,
#  'read': 550,
#  'shape': 551,
#  'attorney': 552,
#  'barr': 553,
#  'certifying': 554,
#  'conversation': 555,
#  'establishing': 556,
#  'executive': 557,
#  'general': 558,
#  'interviewed': 559,
#  'latest': 560,
#  'order': 561,
#  'practices': 562,
#  'reform': 563,
#  'standards': 564,
#  '️': 565,
#  'barrett': 566,
#  'gorsuch': 567,
#  'kavanaugh': 568,
#  '1995': 569,
#  'blacks': 570,
#  'dive': 571,
#  'dropped': 572,
#  'hispanics': 573,
#  'imprisonment': 574,
#  'jail': 575,
#  'led': 576,
#  'percentage': 577,
#  'beat': 578,
#  'businessesour': 579,
#  'continues': 580,
#  'expectations': 581,
#  'extraordinary': 582,
#  'foundationand': 583,
#  'nation_s': 584,
#  'scale': 585,
#  'speed': 586,
#  'strong': 587,
#  '400': 588,
#  'border': 589,
#  'constructed': 590,
#  'miles': 591,
#  'wall': 592,
#  'care': 593,
#  'choice': 594,
#  'competition': 595,
#  'costs': 596,
#  'greatest': 597,
#  'lower': 598,
#  'patients': 599,
#  'true': 600,
#  '_ash': 601,
#  'addressing': 602,
#  'barriers': 603,
#  'cell': 604,
#  'disease': 605,
#  'facing': 606,
#  'healthcare': 607,
#  'long-standing': 608,
#  'plan': 609,
#  'providing': 610,
#  'scd': 611,
#  'sickle': 612,
#  'ways': 613,
#  'attribute': 614,
#  'behalf': 615,
#  'credit': 616,
#  'despite': 617,
#  'media_s': 618,
#  'peopleresulting': 619,
#  'proper': 620,
#  'refusal': 621,
#  'results': 622,
#  'tangible': 623,
#  'changing': 624,
#  'game': 625,
#  'healthcareputting': 626,
#  'seniors': 627,
#  'companies': 628,
#  'covered': 629,
#  'disclose': 630,
#  'drugs': 631,
#  'insurance': 632,
#  'pay': 633,
#  'prescription': 634,
#  'price': 635,
#  'public': 636,
#  'required': 637,
#  'services': 638,
#  'approach': 639,
#  'break': 640,
#  'brooke': 641,
#  'collaborative': 642,
#  'indian': 643,
#  'native': 644,
#  'offered': 645,
#  'partnering': 646,
#  'represents': 647,
#  'responsive': 648,
#  'rollins': 649,
#  'sweeney': 650,
#  'talk': 651,
#  'tara': 652,
#  'washington': 653,
#  'write': 654,
#  '27': 655,
#  '700': 656,
#  'beaches': 657,
#  'clean': 658,
#  'environmentwith': 659,
#  'floridians': 660,
#  'ingenuity': 661,
#  'investing': 662,
#  'keeping': 663,
#  'pride': 664,
#  'problemplastic': 665,
#  'solve': 666,
#  'waste': 667,
#  '3,850': 668,
#  '8': 669,
#  'gains': 670,
#  'office3': 671,
#  'times': 672,
#  'total': 673,
#  'coming': 674,
#  'ability': 675,
#  'financial': 676,
#  'including': 677,
#  'media': 678,
#  'news': 679,
#  'obligation': 680,
#  'points': 681,
#  'resolve': 682,
#  'share': 683,
#  'spirit': 684,
#  'headlines': 685,
#  'justicea': 686,
#  'major': 687,
#  'momentum': 688,
#  'reopens': 689,
#  '1947': 690,
#  'close': 691,
#  'cylinders': 692,
#  'kicking': 693,
#  'kudlow': 694,
#  'larry': 695,
#  'remotely': 696,
#  'thing': 697,
#  'annual': 698,
#  'jumped': 699,
#  'quarterthe': 700,
#  '1600': 701,
#  'classincluding': 702,
#  'concerns': 703,
#  'daily': 704,
#  'establishment': 705,
#  'listen': 706,
#  'lobbyists': 707,
#  'long': 708,
#  'moreignored': 709,
#  'party': 710,
#  'political': 711,
#  'tanks': 712,
#  'think': 713,
#  'wanted': 714,
#  'commitment': 715,
#  'pandemicand': 716,
#  'sure': 717,
#  'availableincluding': 718,
#  'combating': 719,
#  'dismantling': 720,
#  'human': 721,
#  'means': 722,
#  'trafficking': 723,
#  'criminalsincluding': 724,
#  'gangs': 725,
#  'ms-13from': 726,
#  'offenses': 727,
#  'repeat': 728,
#  'victims': 729,
#  'violent': 730,
#  'borders': 731,
#  'charge': 732,
#  'deadly': 733,
#  'flow': 734,
#  'inadequate': 735,
#  'smuggling': 736,
#  'southern': 737,
#  'administration_s': 738,
#  'agents': 739,
#  'arizona': 740,
#  'barrier': 741,
#  'dilapidated': 742,
#  'federal': 743,
#  'hitting': 744,
#  'hold': 745,
#  'insufficient': 746,
#  'jackpot': 747,
#  'line': 748,
#  'replacing': 749,
#  'transforming': 750,
#  'yuma': 751,
#  'base': 752,
#  'compared': 753,
#  'fy': 754,
#  'industrial': 755,
#  'obama': 756,
#  'spending': 757,
#  'todayone': 758,
#  '62': 759,
#  '9,800the': 760,
#  'pointsthe': 761,
#  'winning': 762,
#  'carr': 763,
#  'douglas': 764,
#  'obama-biden': 765,
#  'slowest': 766,
#  'sluggish': 767,
#  'canyon': 768,
#  'grand': 769,
#  'receive': 770,
#  'set': 771,
#  'bureaucracy': 772,
#  'challenges': 773,
#  'hard': 774,
#  'invest': 775,
#  'life': 776,
#  'once-forgotten': 777,
#  'rural': 778,
#  'turned': 779,
#  '920,000': 780,
#  'nevada': 781,
#  'nursing': 782,
#  'shipped': 783,
#  'staff': 784,
#  'students': 785,
#  'teachers': 786,
#  'testing': 787,
#  'they_ll': 788,
#  'birthright': 789,
#  'current': 790,
#  'government': 791,
#  'interests': 792,
#  'lady': 793,
#  'long-term': 794,
#  'partnership': 795,
#  'tribal': 796,
#  'understands': 797,
#  'victimization': 798,
#  'alaska': 799,
#  'children': 800,
#  'combat': 801,
#  'crisis': 802,
#  'decisive': 803,
#  'indians': 804,
#  'missing': 805,
#  'murdered': 806,
#  'natives': 807,
#  'particularly': 808,
#  'took': 809,
#  'tragedy': 810,
#  'develop': 811,
#  'explore': 812,
#  'free': 813,
#  'healthy': 814,
#  'key': 815,
#  'minerals': 816,
#  'recognizes': 817,
#  'responsibly': 818,
#  'wyoming': 819,
#  'depleted': 820,
#  'deroy': 821,
#  'firepower': 822,
#  'forge': 823,
#  'murdock': 824,
#  'potential': 825,
#  '42': 826,
#  'affordable': 827,
#  'cornerstone': 828,
#  'electric': 829,
#  'infrastructure': 830,
#  'missouri': 831,
#  'modern': 832,
#  'nebraska': 833,
#  'prosperity': 834,
#  'reliable': 835,
#  '9,800': 836,
#  'officemore': 837,
#  'typical': 838,
#  'wallets': 839,
#  '11': 840,
#  'agricultural': 841,
#  'awarded': 842,
#  'entrepreneurs': 843,
#  'expand': 844,
#  'grants': 845,
#  'partnerships': 846,
#  '110': 847,
#  '500': 848,
#  'alike': 849,
#  'authorized': 850,
#  'box': 851,
#  'fresh': 852,
#  'program': 853,
#  'tables': 854,
#  'week': 855,
#  '580,000': 856,
#  'reopening': 857,
#  'step': 858,
#  'dedicated': 859,
#  'getting': 860,
#  '12': 861,
#  'medicare': 862,
#  'premiums': 863,
#  '20,000': 864,
#  'administrations': 865,
#  'bolstered': 866,
#  'cutting': 867,
#  'petroleum': 868,
#  'prioritized': 869,
#  'red': 870,
#  'tape': 871,
#  'benefited': 872,
#  'deduction': 873,
#  'doubled': 874,
#  'passage': 875,
#  'standard': 876,
#  '136': 877,
#  '20': 878,
#  '23,000': 879,
#  'accounts': 880,
#  'additional': 881,
#  'billion': 882,
#  'employs': 883,
#  'fracking': 884,
#  'homes': 885,
#  '80,000': 886,
#  'able': 887,
#  'accounting': 888,
#  'canada': 889,
#  'destinations': 890,
#  'export': 891,
#  'exports': 892,
#  'mexico': 893,
#  'sell': 894,
#  'growing': 895,
#  'homeownership': 896,
#  'mortgages': 897,
#  'raise': 898,
#  'relief': 899,
#  '2,000+': 900,
#  '5,292': 901,
#  'cutscompared': 902,
#  'decline': 903,
#  'following': 904,
#  'inflation-adjusted': 905,
#  'median': 906,
#  'auto': 907,
#  'broke': 908,
#  'cut': 909,
#  'employment': 910,
#  'failures': 911,
#  'hundreds': 912,
#  'losing': 913,
#  'sector': 914,
#  'seeing': 915,
#  'stood': 916,
#  'suffered': 917,
#  'thousands': 918,
#  'worst': 919,
#  '115th': 920,
#  'amy': 921,
#  'associate': 922,
#  'committee': 923,
#  'coney': 924,
#  'confirmed': 925,
#  'court': 926,
#  'judiciary': 927,
#  'senate': 928,
#  'shortly': 929,
#  'supreme': 930,
#  'sworn': 931,
#  'unanimous': 932,
#  'vote': 933,
#  'best': 934,
#  'confidence': 935,
#  'discharge': 936,
#  'duties': 937,
#  'expressed': 938,
#  'grateful': 939,
#  'pledge': 940,
#  'constitutional': 941,
#  'oath': 942,
#  'ask': 943,
#  'courage': 944,
#  'god': 945,
#  'wisdom': 946,
#  'heritage': 947,
#  'heroes': 948,
#  'lose': 949,
#  'ceremony': 950,
#  'child': 951,
#  'duty': 952,
#  'fulfilling': 953,
#  'generation': 954,
#  'passes': 955,
#  'possible': 956,
#  'sustain': 957,
#  'traditions': 958,
#  'understand': 959,
#  'virtues': 960,
#  'want': 961,
#  'watching': 962,
#  'based': 963,
#  'clear': 964,
#  'constitution': 965,
#  'faithful': 966,
#  'issue': 967,
#  'reading': 968,
#  'rulings': 969,
#  'solely': 970,
#  'written': 971,
#  'courtand': 972,
#  'fifth': 973,
#  'mother': 974,
#  'school-aged': 975,
#  'woman': 976,
#  'brilliant': 977,
#  'land': 978,
#  'legal': 979,
#  'outstanding': 980,
#  'scholars': 981,
#  'fair': 982,
#  'impartial': 983,
#  'momentous': 984,
#  'rule': 985,
#  'honorable': 986,
#  'participates': 987,
#  'swearing-in': 988,
#  '9:00': 989,
#  'et': 990,
#  'participate': 991,
#  'pm': 992,
#  'announce': 993,
#  'couple': 994,
#  'friday': 995,
#  'significant': 996,
#  '2,500': 997,
#  'electricity': 998,
#  'revolution': 999,
#  ...}

# %%
# count of how many times a word token occurs within a tweets
tweets_bow = [token_id.doc2bow(tweet) for tweet in all_tweets['Tweet']]
# print(tweets_bow)

# %%
# Generate LDA model
import gensim
Lda = gensim.models.ldamodel.LdaModel

# Running and Training LDA model on the document term matrix.
ldamodel = Lda(tweets_bow, num_topics=13, id2word = token_id, passes = 250, chunksize = 20)
# 907  1301533937613799426  2020-09-03 14:54:06+00:00
# 908  1301530918751006720  2020-09-03 14:42:06+00:00
# 909  1301528549040496640  2020-09-03 14:32:41+00:00
# 910  1301328055932268546  2020-09-03 01:16:00+00:00
#
#                                                  Tweet  Reply_count  \
# 0    [all-time, percent, low, record, official, lif...         1320
# 1    [robb, recent, economic, job, west, confirm, s...          592
# 2                   [watch, peacenot, waris, breaking]         1094
# 3    [arab-muslim, agreement, sudan, world, peace, ...          831
# 4    [announced, arab, year, neighbors, secured, he...          469
# ..                                                 ...          ...
# 906                                  [briefing, holds]         2226
# 907                        [pelosi, nancy, rules, set]         2949
# 908  [lost, cuomo, governor, vivid, control, state,...         1053
# 909  [ability, hours, federal, help, democrat, refu...          950
# 910  [daily, past, heroes, cherish, end, 75th, tear...          470
#
#      Retweet_count  Like_count    FRE Sentiment  Neg_pol  Pos_pol  ...  \
# 0             1066        4808  74.19  Negative    0.240    0.000  ...
# 1              467        2611  69.62  Positive    0.055    0.072  ...
# 2             1331        6281  80.28   Neutral    0.000    0.000  ...
# 3              962        5430  63.19  Positive    0.000    0.361  ...
# 4              636        3281  68.60  Positive    0.000    0.234  ...
# ..             ...         ...    ...       ...      ...      ...  ...
# 906           1934        6435  92.80   Neutral    0.000    0.000  ...
# 907           1994        7227  67.76   Neutral    0.000    0.000  ...
# 908           1908        5443  75.71  Negative    0.064    0.000  ...
# 909            906        3292  81.63  Positive    0.118    0.224  ...
# 910            910        4025  49.83  Positive    0.000    0.215  ...
#
#        Topic3    Topic4    Topic5    Topic6    Topic7    Topic8    Topic9  \
# 0    0.000000  0.000000  0.000000  0.000000  0.863625  0.000000  0.000000
# 1    0.000000  0.000000  0.000000  0.089701  0.000000  0.000000  0.000000
# 2    0.025539  0.025539  0.025539  0.025539  0.025539  0.025539  0.025539
# 3    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4    0.379849  0.000000  0.000000  0.000000  0.000000  0.000000  0.067294
# ..        ...       ...       ...       ...       ...       ...       ...
# 906  0.025641  0.025641  0.692306  0.025641  0.025641  0.025641  0.025641
# 907  0.015385  0.015385  0.015385  0.015385  0.015385  0.015385  0.015385
# 908  0.401479  0.011418  0.011418  0.324179  0.011418  0.011418  0.011418
# 909  0.084311  0.251145  0.000000  0.000000  0.000000  0.000000  0.000000
# 910  0.070487  0.268478  0.070414  0.000000  0.000000  0.139070  0.280642
#
#       Topic10   Topic11   Topic12
# 0    0.076425  0.000000  0.000000
# 1    0.000000  0.000000  0.000000
# 2    0.025539  0.025539  0.025539
# 3    0.000000  0.000000  0.000000
# 4    0.000000  0.317253  0.000000
# ..        ...       ...       ...
# 906  0.025641  0.025641  0.025641
# 907  0.015385  0.015385  0.015385
# 908  0.011418  0.011418  0.011418
# 909  0.000000  0.000000  0.000000
# 910  0.000000  0.000000  0.000000
#
# [911 rows x 31 columns]

# %%
# save dataframe in pickle
save_tweets=open('Trump_tweets','wb') #  must write byte
pickle.dump(all_tweets,save_tweets)
save_tweets.close()

# %%
tweets_open=open('Trump_tweets','rb')
all_tweets=pickle.load(tweets_open)

# %%
all_tweets.describe()
# Out:
#                  ID   Reply_count  Retweet_count    Like_count         FRE  \
# count  9.110000e+02    911.000000     911.000000    911.000000  911.000000
# mean   1.312314e+18    823.746432     971.129528   4551.443469   48.958057
# std    6.769166e+15   1082.472139     976.146231   4430.580072   20.035735
# min    1.301328e+18     25.000000     153.000000    730.000000  -28.700000
# 25%    1.306310e+18    320.000000     427.000000   1980.000000   36.280000
# 50%    1.310673e+18    532.000000     679.000000   3299.000000   49.820000
# 75%    1.318715e+18    933.500000    1102.000000   5138.500000   61.330000
# max    1.323406e+18  14638.000000    9944.000000  43596.000000  112.090000
#
#           Neg_pol     Pos_pol     Neu_pol    Compound  Tweet_length  ...  \
# count  911.000000  911.000000  911.000000  911.000000    911.000000  ...
# mean     0.048748    0.153319    0.797936    0.313098     13.111965  ...
# std      0.084706    0.129724    0.142505    0.484420      5.545276  ...
# min      0.000000    0.000000    0.200000   -0.955200      2.000000  ...
# 25%      0.000000    0.000000    0.694000    0.000000      9.000000  ...
# 50%      0.000000    0.148000    0.797000    0.440400     13.000000  ...
# 75%      0.078000    0.237500    0.904000    0.734500     17.000000  ...
# max      0.456000    0.800000    1.000000    0.979300     29.000000  ...
#
#            Topic3      Topic4      Topic5      Topic6      Topic7      Topic8  \
# count  911.000000  911.000000  911.000000  911.000000  911.000000  911.000000
# mean     0.052802    0.120556    0.094284    0.090158    0.079208    0.035227
# std      0.103432    0.178041    0.169267    0.164660    0.140457    0.096846
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.010780    0.023113    0.010992    0.012470    0.012725    0.000000
# 75%      0.067292    0.166400    0.113408    0.106922    0.107259    0.015385
# max      0.773121    0.916144    0.934261    0.820684    0.863625    0.903827
#
#            Topic9     Topic10     Topic11     Topic12
# count  911.000000  911.000000  911.000000  911.000000
# mean     0.059962    0.109911    0.040906    0.073249
# std      0.131982    0.170886    0.103489    0.157165
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.015386    0.000000    0.000000
# 75%      0.055143    0.147290    0.019195    0.053720
# max      0.922030    0.930535    0.884613    0.923075
#
# [8 rows x 27 columns]

# %% [markdown]
# # Negative Binnomial Regression Model

# %% [markdown]
# ###### I have used following link for NB model https://towardsdatascience.com/negative-binomial-regression-f99031bb25b4

# %% [markdown]
# ###### NB model for Reply_count

# %%
# load dataset using pandas
df = all_tweets.iloc[:, 3:]
df = df.drop(['Tweet_time', 'Sentiment', 'Neg_pol', 'Pos_pol', 'Neu_pol'], axis = 1)
# df.columns

# create training and testing sets
sample = np.random.rand(len(df)) < 0.8
df_train = df[sample]
df_test = df[~sample]
print('Training data set length='+str(len(df_train)))
print('Testing data set length='+str(len(df_test)))

# step 1: Poission regression model on training set to find rate lambda
# here we used patsy 
expr = """Reply_count ~ FRE + Compound + Tweet_length + Strong + Weak +
Hostile + Pleasure + Topic0 + Topic1 + Topic2 + Topic3 +  Topic4 + Topic5 + Topic6 +
Topic7 + Topic8 + Topic9 + Topic10 + Topic11 + Topic12"""

# training and testing datset on training set
y_train, X_train = dmatrices(expr, df_train, return_type='dataframe')
y_test, X_test = dmatrices(expr, df_test, return_type='dataframe')

# train the Poisson regression model on the training data set
poisson_training_results = sm.GLM(y_train, X_train, family=sm.families.Poisson()).fit()
# print(poisson_training_results.summary())

# rate vector
# print(poisson_training_results.mu)
# print(len(poisson_training_results.mu))

# step 2: auxiliary OLS regression model on the data set to get alpha
# add lambda in dataframe
df_train['Reply_LAMBDA'] = poisson_training_results.mu

# add alpha in dataframe
df_train['AUX_OLS_DEP'] = df_train.apply(lambda x: ((x['Reply_count'] - x['Reply_LAMBDA'])**2 - x['Reply_LAMBDA']) / x['Reply_LAMBDA'], axis=1)
ols_expr = """AUX_OLS_DEP ~ Reply_LAMBDA - 1"""

aux_olsr_results = smf.ols(ols_expr, df_train).fit()
print(aux_olsr_results.params)

# print t-value
aux_olsr_results.tvalues

# Step 3: train NB2 model on traing data
nb2_training_results = sm.GLM(y_train, X_train,family=sm.families.NegativeBinomial(alpha=aux_olsr_results.params[0])).fit()
print(nb2_training_results.summary())

# Step 4: make predictions
nb2_predictions = nb2_training_results.get_prediction(X_test)

predictions_summary_frame = nb2_predictions.summary_frame()
print(predictions_summary_frame)
# Out:
# Training data set length=715
# Testing data set length=196
# Reply_LAMBDA    1.475196
# dtype: float64
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            Reply_count   No. Observations:                  715
# Model:                            GLM   Df Residuals:                      694
# Model Family:        NegativeBinomial   Df Model:                           20
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -5554.7
# Date:                Thu, 06 May 2021   Deviance:                       330.88
# Time:                        19:36:08   Pearson chi2:                     557.
# No. Iterations:                    12
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        1.1220      2.154      0.521      0.602      -3.099       5.343
# FRE              0.0025      0.003      1.002      0.316      -0.002       0.007
# Compound        -0.1948      0.104     -1.868      0.062      -0.399       0.010
# Tweet_length    -0.0236      0.013     -1.859      0.063      -0.049       0.001
# Strong           1.3897      0.491      2.828      0.005       0.427       2.353
# Weak             2.3392      2.264      1.033      0.302      -2.099       6.777
# Hostile         -0.0791      2.088     -0.038      0.970      -4.172       4.014
# Pleasure         2.8140      3.226      0.872      0.383      -3.510       9.138
# Topic0           5.5882      2.349      2.379      0.017       0.984      10.192
# Topic1           6.1155      2.362      2.589      0.010       1.486      10.745
# Topic2          -2.8540      9.988     -0.286      0.775     -22.430      16.722
# Topic3           6.1304      2.371      2.586      0.010       1.483      10.777
# Topic4           5.8571      2.351      2.491      0.013       1.249      10.465
# Topic5           6.2972      2.335      2.697      0.007       1.721      10.873
# Topic6           5.9777      2.339      2.556      0.011       1.394      10.562
# Topic7           5.9951      2.356      2.545      0.011       1.377      10.613
# Topic8           6.2607      2.355      2.659      0.008       1.645      10.876
# Topic9           5.3094      2.352      2.257      0.024       0.699       9.920
# Topic10          5.7884      2.362      2.451      0.014       1.160      10.417
# Topic11          5.0794      2.376      2.138      0.033       0.422       9.736
# Topic12          5.8078      2.358      2.463      0.014       1.187      10.429
# ================================================================================
#             mean     mean_se  mean_ci_lower  mean_ci_upper
# 5     558.963609  186.282641     290.876349    1074.134483
# 12    463.402085  100.263617     303.241371     708.153679
# 14    613.128105  132.743976     401.110169     937.214016
# 19    562.964710  125.490458     363.697106     871.409918
# 20   1098.694525  321.890070     618.722852    1951.002223
# ..           ...         ...            ...            ...
# 870   331.969881  105.168873     178.416883     617.676985
# 872   887.764799  137.067718     655.957103    1201.490670
# 875   861.738748  134.691241     634.353535    1170.630618
# 885  1434.379467  315.027978     932.647443    2206.025942
# 896   633.965241  157.276153     389.849164    1030.942127
#
# [196 rows x 4 columns]
# <ipython-input-74-4b63a5c907c6>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Reply_LAMBDA'] = poisson_training_results.mu
# <ipython-input-74-4b63a5c907c6>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['AUX_OLS_DEP'] = df_train.apply(lambda x: ((x['Reply_count'] - x['Reply_LAMBDA'])**2 - x['Reply_LAMBDA']) / x['Reply_LAMBDA'], axis=1)

# %% [markdown]
# ###### NB model for Like_count

# %%
# step 1: Poission regression model on training set to find rate lambda
# here we used patsy 
expr = """Like_count ~ FRE + Compound + Tweet_length + Strong + Weak +
Hostile + Pleasure + Topic0 + Topic1 + Topic2 + Topic3 +  Topic4 + Topic5 + Topic6 +
Topic7 + Topic8 + Topic9 + Topic10 + Topic11 + Topic12"""

# training and testing datset on training set
y_train, X_train = dmatrices(expr, df_train, return_type='dataframe')
y_test, X_test = dmatrices(expr, df_test, return_type='dataframe')

# train the Poisson regression model on the training data set
poisson_training_results = sm.GLM(y_train, X_train, family=sm.families.Poisson()).fit()
# print(poisson_training_results.summary())

# rate vector
# print(poisson_training_results.mu)
# print(len(poisson_training_results.mu))

# step 2: auxiliary OLS regression model on the data set to get alpha
# add lambda in dataframe
df_train['Like_LAMBDA'] = poisson_training_results.mu

# add alpha in dataframe
df_train['AUX_OLS_DEP'] = df_train.apply(lambda x: ((x['Like_count'] - x['Like_LAMBDA'])**2 - x['Like_LAMBDA']) / x['Like_LAMBDA'], axis=1)
ols_expr = """AUX_OLS_DEP ~ Like_LAMBDA - 1"""

aux_olsr_results = smf.ols(ols_expr, df_train).fit()
print(aux_olsr_results.params)

# print t-value
aux_olsr_results.tvalues

# Step 3: train NB2 model on traing data
nb2_training_results = sm.GLM(y_train, X_train,family=sm.families.NegativeBinomial(alpha=aux_olsr_results.params[0])).fit()
print(nb2_training_results.summary())

# Step 4: make predictions
nb2_predictions = nb2_training_results.get_prediction(X_test)

predictions_summary_frame = nb2_predictions.summary_frame()
print(predictions_summary_frame)
# Out:
# Like_LAMBDA    0.842348
# dtype: float64
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:             Like_count   No. Observations:                  736
# Model:                            GLM   Df Residuals:                      715
# Model Family:        NegativeBinomial   Df Model:                           20
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -6891.3
# Date:                Thu, 06 May 2021   Deviance:                       467.51
# Time:                        01:33:34   Pearson chi2:                     760.
# No. Iterations:                    10
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        6.8510      1.582      4.330      0.000       3.750       9.952
# FRE              0.0013      0.002      0.709      0.478      -0.002       0.005
# Compound        -0.1048      0.078     -1.339      0.180      -0.258       0.049
# Tweet_length    -0.0125      0.009     -1.343      0.179      -0.031       0.006
# Strong           1.0493      0.361      2.907      0.004       0.342       1.757
# Weak             1.5890      1.862      0.853      0.393      -2.060       5.238
# Hostile          0.0682      1.574      0.043      0.965      -3.016       3.152
# Pleasure        -0.5897      2.441     -0.242      0.809      -5.374       4.195
# Topic0           1.5458      1.728      0.894      0.371      -1.841       4.933
# Topic1           1.6629      1.734      0.959      0.337      -1.735       5.061
# Topic2           5.3657      7.420      0.723      0.470      -9.176      19.908
# Topic3           1.7247      1.757      0.982      0.326      -1.719       5.169
# Topic4           1.7260      1.740      0.992      0.321      -1.683       5.136
# Topic5           1.5893      1.715      0.927      0.354      -1.772       4.951
# Topic6           0.8998      1.719      0.523      0.601      -2.470       4.270
# Topic7           1.9696      1.738      1.133      0.257      -1.437       5.376
# Topic8           1.7938      1.734      1.034      0.301      -1.605       5.193
# Topic9           1.5459      1.731      0.893      0.372      -1.847       4.939
# Topic10          1.4926      1.733      0.861      0.389      -1.904       4.889
# Topic11          1.3486      1.755      0.768      0.442      -2.091       4.789
# Topic12          2.1939      1.746      1.257      0.209      -1.228       5.616
# ================================================================================
#             mean      mean_se  mean_ci_lower  mean_ci_upper
# 1    3777.339322   599.868946    2766.999026    5156.594642
# 10   2532.813366   387.676736    1876.362862    3418.924813
# 12   3069.678255   502.883028    2226.623095    4231.935171
# 22   3741.165425   626.332863    2694.646000    5194.121503
# 27   4026.135063   843.288261    2670.552741    6069.815923
# ..           ...          ...            ...            ...
# 891  3917.336867   409.403058    3191.768414    4807.845101
# 892  6176.693951   752.514705    4864.666646    7842.582223
# 893  3986.442357   489.082955    3134.400498    5070.099586
# 894  4785.161779   770.375147    3490.274325    6560.450874
# 908  5811.945057  1007.348988    4137.975626    8163.099157
#
# [175 rows x 4 columns]
# <ipython-input-70-21f6930b2dc0>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Like_LAMBDA'] = poisson_training_results.mu
# <ipython-input-70-21f6930b2dc0>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['AUX_OLS_DEP'] = df_train.apply(lambda x: ((x['Like_count'] - x['Like_LAMBDA'])**2 - x['Like_LAMBDA']) / x['Like_LAMBDA'], axis=1)

# %% [markdown]
# ###### NB model for Retweet count

# %%
# step 1: Poission regression model on training set to find rate lambda
# here we used patsy 
expr = """Retweet_count ~ FRE + Compound + Tweet_length + Strong + Weak +
Hostile + Pleasure + Topic0 + Topic1 + Topic2 + Topic3 +  Topic4 + Topic5 + Topic6 +
Topic7 + Topic8 + Topic9 + Topic10 + Topic11 + Topic12"""

# training and testing datset on training set
y_train, X_train = dmatrices(expr, df_train, return_type='dataframe')
y_test, X_test = dmatrices(expr, df_test, return_type='dataframe')

# train the Poisson regression model on the training data set
poisson_training_results = sm.GLM(y_train, X_train, family=sm.families.Poisson()).fit()
# print(poisson_training_results.summary())

# rate vector
# print(poisson_training_results.mu)
# print(len(poisson_training_results.mu))

# step 2: auxiliary OLS regression model on the data set to get alpha
# add lambda in dataframe
df_train['Retweet_LAMBDA'] = poisson_training_results.mu

# add alpha in dataframe
df_train['AUX_OLS_DEP'] = df_train.apply(lambda x: ((x['Retweet_count'] - x['Retweet_LAMBDA'])**2 - x['Retweet_LAMBDA']) / x['Retweet_LAMBDA'], axis=1)
ols_expr = """AUX_OLS_DEP ~ Retweet_LAMBDA - 1"""

aux_olsr_results = smf.ols(ols_expr, df_train).fit()
print(aux_olsr_results.params)

# print t-value
aux_olsr_results.tvalues

# Step 3: train NB2 model on traing data
nb2_training_results = sm.GLM(y_train, X_train,family=sm.families.NegativeBinomial(alpha=aux_olsr_results.params[0])).fit()
print(nb2_training_results.summary())

# Step 4: make predictions
nb2_predictions = nb2_training_results.get_prediction(X_test)

predictions_summary_frame = nb2_predictions.summary_frame()
print(predictions_summary_frame)
# Out:
# Retweet_LAMBDA    0.931415
# dtype: float64
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:          Retweet_count   No. Observations:                  726
# Model:                            GLM   Df Residuals:                      705
# Model Family:        NegativeBinomial   Df Model:                           20
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -5698.9
# Date:                Thu, 06 May 2021   Deviance:                       422.61
# Time:                        01:19:45   Pearson chi2:                     711.
# No. Iterations:                     9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        4.7133      1.690      2.789      0.005       1.401       8.026
# FRE              0.0008      0.002      0.422      0.673      -0.003       0.005
# Compound        -0.1685      0.081     -2.090      0.037      -0.327      -0.010
# Tweet_length    -0.0152      0.010     -1.510      0.131      -0.035       0.005
# Strong           0.7546      0.375      2.013      0.044       0.020       1.489
# Weak             2.7804      1.877      1.481      0.139      -0.898       6.459
# Hostile         -1.3799      1.645     -0.839      0.401      -4.603       1.843
# Pleasure         0.4410      3.131      0.141      0.888      -5.696       6.578
# Topic0           2.0293      1.842      1.102      0.270      -1.580       5.639
# Topic1           2.4415      1.859      1.314      0.189      -1.201       6.084
# Topic2          -1.0281      7.934     -0.130      0.897     -16.579      14.522
# Topic3           2.2351      1.868      1.196      0.232      -1.426       5.896
# Topic4           2.4197      1.855      1.305      0.192      -1.215       6.055
# Topic5           2.5778      1.835      1.405      0.160      -1.019       6.175
# Topic6           1.7446      1.838      0.949      0.343      -1.859       5.348
# Topic7           2.7496      1.861      1.477      0.140      -0.898       6.397
# Topic8           2.5467      1.849      1.378      0.168      -1.077       6.170
# Topic9           2.3869      1.867      1.278      0.201      -1.273       6.046
# Topic10          2.2956      1.858      1.236      0.217      -1.346       5.937
# Topic11          2.5017      1.868      1.339      0.180      -1.159       6.162
# Topic12          2.8293      1.868      1.514      0.130      -0.833       6.491
# ================================================================================
#             mean     mean_se  mean_ci_lower  mean_ci_upper
# 5    1060.247652  278.785196     633.270755    1775.109736
# 7    1013.994839  341.618114     523.917873    1962.493715
# 14    763.665550  128.292778     549.420325    1061.455220
# 17    708.597145  194.674979     413.567396    1214.094531
# 18    533.910992  133.606041     326.936901     871.914263
# ..           ...         ...            ...            ...
# 893   794.158817  104.550202     613.546585    1027.938615
# 894   994.300956  158.728170     727.166368    1359.571117
# 898   984.264712  403.631458     440.603119    2198.752077
# 900   693.543398   79.407361     554.134497     868.024727
# 910   854.387318  168.171042     580.912624    1256.604968
#
# [185 rows x 4 columns]
# <ipython-input-49-11007ea4ef59>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Retweet_LAMBDA'] = poisson_training_results.mu
# <ipython-input-49-11007ea4ef59>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['AUX_OLS_DEP'] = df_train.apply(lambda x: ((x['Retweet_count'] - x['Retweet_LAMBDA'])**2 - x['Retweet_LAMBDA']) / x['Retweet_LAMBDA'], axis=1)
